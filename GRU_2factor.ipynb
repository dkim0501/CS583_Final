# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import GRU
import matplotlib.pyplot as plt
import time

# Download stock data
symbol = "TSLA"
data = yf.download(symbol, start="2020-01-01", end="2023-09-01")
price_volume_data = data[['Close', 'Volume']].values

# Scale the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(price_volume_data)

# Split train and test set
train_size = int(len(scaled_data)*0.7) # 70% training, 30% testing
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), :]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# calling the create dataset function to split the data into 
# input output datasets with time step 60
time_step = 60
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)



# build GRU model
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # input layer
model.add(GRU(50, return_sequences=True))  # hidden layer
model.add(GRU(50))  # hidden layer
model.add(Dense(1))  # output layer
model.compile(loss='mean_squared_error', optimizer='adam')

# summarize model
model.summary()

# check the running time
start_time = time.time()

model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64, verbose=1)

# end to check the time
end_time = time.time()

# print the running time
print("Learning time: ", end_time - start_time, "seconds")

# Prediction
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# transform to original form
train_predict = scaler.inverse_transform(np.column_stack((train_predict, np.zeros_like(train_predict))))
test_predict = scaler.inverse_transform(np.column_stack((test_predict, np.zeros_like(test_predict))))
train_predict = train_predict[:, 0]
test_predict = test_predict[:, 0]

Y_train_orig = scaler.inverse_transform(np.column_stack((Y_train, np.zeros_like(Y_train))))[:, 0]
Y_test_orig = scaler.inverse_transform(np.column_stack((Y_test, np.zeros_like(Y_test))))[:, 0]

# Calculate RMSE
print("Training RMSE:", np.sqrt(mean_squared_error(Y_train_orig, train_predict)))
print("Testing RMSE:", np.sqrt(mean_squared_error(Y_test_orig, test_predict)))

## Plotting
look_back = 60
trainPredictPlot = np.empty_like(price_volume_data[:, 0])
trainPredictPlot[:] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back] = train_predict

testPredictPlot = np.empty_like(price_volume_data[:, 0])
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1:len(scaled_data) - 1] = test_predict

plt.plot(scaler.inverse_transform(scaled_data)[:, 0])
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show() # Orange is the TrainPredictPlot, Green is TestPredictPlot
# Out:
# [*********************100%***********************]  1 of 1 completed
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 60, 50)            8100
#
#  gru_4 (GRU)                 (None, 60, 50)            15300
#
#  gru_5 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38751 (151.37 KB)
# Trainable params: 38751 (151.37 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 8s 199ms/step - loss: 0.0563 - val_loss: 0.0059
# Epoch 2/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0109 - val_loss: 0.0023
# Epoch 3/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 4/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 5/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 6/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 7/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 8/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 9/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 10/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 11/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 12/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 13/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 14/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 15/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 16/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 17/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 9.8437e-04
# Epoch 18/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 8.9032e-04
# Epoch 19/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0012 - val_loss: 8.9132e-04
# Epoch 20/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0012 - val_loss: 9.6499e-04
# Epoch 21/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 8.8783e-04
# Epoch 22/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0011 - val_loss: 7.7788e-04
# Epoch 23/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0010 - val_loss: 7.5656e-04
# Epoch 24/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0010 - val_loss: 7.3872e-04
# Epoch 25/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0010 - val_loss: 7.2147e-04
# Epoch 26/100
# 10/10 [==============================] - 1s 82ms/step - loss: 9.8807e-04 - val_loss: 6.9786e-04
# Epoch 27/100
# 10/10 [==============================] - 1s 81ms/step - loss: 9.9650e-04 - val_loss: 6.8694e-04
# Epoch 28/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0010 - val_loss: 8.2854e-04
# Epoch 29/100
# 10/10 [==============================] - 1s 82ms/step - loss: 9.5299e-04 - val_loss: 7.2520e-04
# Epoch 30/100
# 10/10 [==============================] - 1s 80ms/step - loss: 9.2456e-04 - val_loss: 6.5163e-04
# Epoch 31/100
# 10/10 [==============================] - 1s 81ms/step - loss: 9.0085e-04 - val_loss: 6.5502e-04
# Epoch 32/100
# 10/10 [==============================] - 1s 81ms/step - loss: 9.1223e-04 - val_loss: 6.2103e-04
# Epoch 33/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.6837e-04 - val_loss: 6.1519e-04
# Epoch 34/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.4520e-04 - val_loss: 6.3020e-04
# Epoch 35/100
# 10/10 [==============================] - 1s 81ms/step - loss: 8.4087e-04 - val_loss: 6.5408e-04
# Epoch 36/100
# 10/10 [==============================] - 1s 80ms/step - loss: 8.6325e-04 - val_loss: 5.8460e-04
# Epoch 37/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.8658e-04 - val_loss: 6.1684e-04
# Epoch 38/100
# 10/10 [==============================] - 1s 80ms/step - loss: 8.5090e-04 - val_loss: 5.6784e-04
# Epoch 39/100
# 10/10 [==============================] - 1s 81ms/step - loss: 8.4366e-04 - val_loss: 5.8134e-04
# Epoch 40/100
# 10/10 [==============================] - 1s 81ms/step - loss: 9.1011e-04 - val_loss: 5.5565e-04
# Epoch 41/100
# 10/10 [==============================] - 1s 81ms/step - loss: 8.1728e-04 - val_loss: 5.4512e-04
# Epoch 42/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.8384e-04 - val_loss: 5.3319e-04
# Epoch 43/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.7203e-04 - val_loss: 5.2847e-04
# Epoch 44/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.7798e-04 - val_loss: 5.5631e-04
# Epoch 45/100
# 10/10 [==============================] - 1s 81ms/step - loss: 8.4791e-04 - val_loss: 5.2063e-04
# Epoch 46/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.9335e-04 - val_loss: 5.1883e-04
# Epoch 47/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.3212e-04 - val_loss: 5.0511e-04
# Epoch 48/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.0736e-04 - val_loss: 5.6821e-04
# Epoch 49/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.8430e-04 - val_loss: 4.9038e-04
# Epoch 50/100
# 10/10 [==============================] - 1s 81ms/step - loss: 8.3766e-04 - val_loss: 5.9313e-04
# Epoch 51/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.2424e-04 - val_loss: 4.8236e-04
# Epoch 52/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.2407e-04 - val_loss: 4.8147e-04
# Epoch 53/100
# 10/10 [==============================] - 1s 80ms/step - loss: 7.2769e-04 - val_loss: 4.7650e-04
# Epoch 54/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.2304e-04 - val_loss: 6.5893e-04
# Epoch 55/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.3748e-04 - val_loss: 4.9841e-04
# Epoch 56/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.1867e-04 - val_loss: 4.5774e-04
# Epoch 57/100
# 10/10 [==============================] - 1s 80ms/step - loss: 7.2050e-04 - val_loss: 5.0251e-04
# Epoch 58/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.4701e-04 - val_loss: 4.6252e-04
# Epoch 59/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.1774e-04 - val_loss: 5.8834e-04
# Epoch 60/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.1568e-04 - val_loss: 4.4109e-04
# Epoch 61/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.1335e-04 - val_loss: 4.3898e-04
# Epoch 62/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.9894e-04 - val_loss: 6.0681e-04
# Epoch 63/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.8967e-04 - val_loss: 5.3068e-04
# Epoch 64/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.8465e-04 - val_loss: 4.2995e-04
# Epoch 65/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.9752e-04 - val_loss: 4.5485e-04
# Epoch 66/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.1858e-04 - val_loss: 4.2589e-04
# Epoch 67/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.4907e-04 - val_loss: 4.9309e-04
# Epoch 68/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.4070e-04 - val_loss: 4.2573e-04
# Epoch 69/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.6678e-04 - val_loss: 4.9472e-04
# Epoch 70/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.6486e-04 - val_loss: 4.2886e-04
# Epoch 71/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.4981e-04 - val_loss: 5.0054e-04
# Epoch 72/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.7610e-04 - val_loss: 4.2334e-04
# Epoch 73/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.4023e-04 - val_loss: 5.0765e-04
# Epoch 74/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.7107e-04 - val_loss: 5.0101e-04
# Epoch 75/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.4341e-04 - val_loss: 4.4985e-04
# Epoch 76/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.4771e-04 - val_loss: 4.1477e-04
# Epoch 77/100
# 10/10 [==============================] - 1s 80ms/step - loss: 6.3983e-04 - val_loss: 4.4096e-04
# Epoch 78/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.4830e-04 - val_loss: 4.2434e-04
# Epoch 79/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.4434e-04 - val_loss: 4.5067e-04
# Epoch 80/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.2466e-04 - val_loss: 3.9715e-04
# Epoch 81/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.1902e-04 - val_loss: 3.9808e-04
# Epoch 82/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.7330e-04 - val_loss: 5.9447e-04
# Epoch 83/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.7688e-04 - val_loss: 4.2902e-04
# Epoch 84/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.5758e-04 - val_loss: 4.3859e-04
# Epoch 85/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.6576e-04 - val_loss: 6.0209e-04
# Epoch 86/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.4300e-04 - val_loss: 4.6879e-04
# Epoch 87/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.8177e-04 - val_loss: 3.9941e-04
# Epoch 88/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.6871e-04 - val_loss: 4.0883e-04
# Epoch 89/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.1641e-04 - val_loss: 6.5596e-04
# Epoch 90/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.5736e-04 - val_loss: 4.2477e-04
# Epoch 91/100
# 10/10 [==============================] - 1s 80ms/step - loss: 6.2710e-04 - val_loss: 3.9973e-04
# Epoch 92/100
# 10/10 [==============================] - 1s 80ms/step - loss: 6.0661e-04 - val_loss: 4.2623e-04
# Epoch 93/100
# 10/10 [==============================] - 1s 79ms/step - loss: 6.6308e-04 - val_loss: 3.8703e-04
# Epoch 94/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.3059e-04 - val_loss: 5.5490e-04
# Epoch 95/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.3660e-04 - val_loss: 4.3930e-04
# Epoch 96/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.7447e-04 - val_loss: 3.8890e-04
# Epoch 97/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.2747e-04 - val_loss: 3.9368e-04
# Epoch 98/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.1725e-04 - val_loss: 4.3144e-04
# Epoch 99/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.5568e-04 - val_loss: 6.2053e-04
# Epoch 100/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.0620e-04 - val_loss: 4.5693e-04
# Learning time:  88.30994462966919 seconds
# 19/19 [==============================] - 1s 16ms/step
# 7/7 [==============================] - 0s 17ms/step
# Training RMSE: 9.696225225026607
# Testing RMSE: 8.248730317573063
