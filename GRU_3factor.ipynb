# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.layers import GRU
import time

# get SPY data
symbol = "TSLA"
start_date = "2020-01-01"
end_date = "2023-09-01"
data = yf.download(symbol, start=start_date, end=end_date)

# get VIX data
vix_data = yf.download("^VIX", start=start_date, end=end_date)
vix_data = vix_data[['Close']]

# make data set 
data = data.join(vix_data, rsuffix='_VIX')

# delete NaN 
data = data.fillna(method='ffill')

# 'Close', 'Volume', 'Close_VIX' - input features 
price_volume_vix_data = data[['Close', 'Volume', 'Close_VIX']].values

# data scaling
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(price_volume_vix_data)

# split train and test set
train_size = int(len(scaled_data) * 0.7)
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

# create dataset 
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), :]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 60
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# build GRU model
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # input layer
model.add(GRU(50, return_sequences=True))  # hidden layer
model.add(GRU(50))  # hidden layer
model.add(Dense(1))  # output layer
model.compile(loss='mean_squared_error', optimizer='adam')

# summarize model
model.summary()

# check the running time
start_time = time.time()

# training model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64, verbose=1)

# end to check the time
end_time = time.time()

# print the running time
print("Learning time: ", end_time - start_time, "seconds")

# prediction
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# transform it to original scale
train_predict = scaler.inverse_transform(np.column_stack((train_predict, np.zeros_like(train_predict), np.zeros_like(train_predict))))
test_predict = scaler.inverse_transform(np.column_stack((test_predict, np.zeros_like(test_predict), np.zeros_like(test_predict))))
train_predict = train_predict[:, 0]
test_predict = test_predict[:, 0]


Y_train_2d = np.expand_dims(Y_train, axis=1)
Y_test_2d = np.expand_dims(Y_test, axis=1)

trainY_original = scaler.inverse_transform(np.column_stack((Y_train_2d, np.zeros_like(Y_train_2d), np.zeros_like(Y_train_2d))))[:, 0]
testY_original = scaler.inverse_transform(np.column_stack((Y_test_2d, np.zeros_like(Y_test_2d), np.zeros_like(Y_test_2d))))[:, 0]

# get RMSE
print("Train RMSE: ", np.sqrt(mean_squared_error(trainY_original, train_predict)))
print("Test RMSE: ", np.sqrt(mean_squared_error(testY_original, test_predict)))

# plotting
look_back = 60
trainPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
trainPredictPlot[:] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back] = train_predict

testPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1:len(scaled_data) - 1] = test_predict

plt.plot(scaler.inverse_transform(scaled_data)[:, 0])
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 60, 50)            8250
#
#  gru_1 (GRU)                 (None, 60, 50)            15300
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 38901 (151.96 KB)
# Trainable params: 38901 (151.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 12s 312ms/step - loss: 0.1193 - val_loss: 0.0441
# Epoch 2/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0174 - val_loss: 0.0070
# Epoch 3/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 4/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 5/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 6/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 7/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 8/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 9/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 10/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 11/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 12/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 13/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 14/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 15/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 16/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 17/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 18/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 9.6033e-04
# Epoch 19/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0011 - val_loss: 9.5429e-04
# Epoch 20/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0011 - val_loss: 8.8111e-04
# Epoch 21/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 22/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0010 - val_loss: 8.8705e-04
# Epoch 23/100
# 10/10 [==============================] - 1s 94ms/step - loss: 9.8853e-04 - val_loss: 0.0010
# Epoch 24/100
# 10/10 [==============================] - 1s 92ms/step - loss: 9.8913e-04 - val_loss: 8.4382e-04
# Epoch 25/100
# 10/10 [==============================] - 1s 93ms/step - loss: 9.4507e-04 - val_loss: 7.1083e-04
# Epoch 26/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0010 - val_loss: 8.6430e-04
# Epoch 27/100
# 10/10 [==============================] - 1s 92ms/step - loss: 9.6340e-04 - val_loss: 8.4351e-04
# Epoch 28/100
# 10/10 [==============================] - 1s 91ms/step - loss: 8.9016e-04 - val_loss: 8.6617e-04
# Epoch 29/100
# 10/10 [==============================] - 1s 92ms/step - loss: 8.8655e-04 - val_loss: 6.9641e-04
# Epoch 30/100
# 10/10 [==============================] - 1s 94ms/step - loss: 8.6563e-04 - val_loss: 6.2789e-04
# Epoch 31/100
# 10/10 [==============================] - 1s 91ms/step - loss: 9.4623e-04 - val_loss: 6.8428e-04
# Epoch 32/100
# 10/10 [==============================] - 1s 93ms/step - loss: 8.4020e-04 - val_loss: 7.4901e-04
# Epoch 33/100
# 10/10 [==============================] - 1s 93ms/step - loss: 8.2893e-04 - val_loss: 6.6806e-04
# Epoch 34/100
# 10/10 [==============================] - 1s 91ms/step - loss: 8.3027e-04 - val_loss: 6.1234e-04
# Epoch 35/100
# 10/10 [==============================] - 1s 90ms/step - loss: 8.0002e-04 - val_loss: 5.9336e-04
# Epoch 36/100
# 10/10 [==============================] - 1s 89ms/step - loss: 8.0273e-04 - val_loss: 5.6903e-04
# Epoch 37/100
# 10/10 [==============================] - 1s 89ms/step - loss: 8.0628e-04 - val_loss: 6.3750e-04
# Epoch 38/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.6236e-04 - val_loss: 6.9518e-04
# Epoch 39/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.6330e-04 - val_loss: 6.5468e-04
# Epoch 40/100
# 10/10 [==============================] - 1s 94ms/step - loss: 7.5397e-04 - val_loss: 5.9742e-04
# Epoch 41/100
# 10/10 [==============================] - 1s 94ms/step - loss: 7.4286e-04 - val_loss: 9.5494e-04
# Epoch 42/100
# 10/10 [==============================] - 1s 89ms/step - loss: 9.1561e-04 - val_loss: 8.5498e-04
# Epoch 43/100
# 10/10 [==============================] - 1s 89ms/step - loss: 7.8122e-04 - val_loss: 5.1414e-04
# Epoch 44/100
# 10/10 [==============================] - 1s 88ms/step - loss: 8.0936e-04 - val_loss: 5.3862e-04
# Epoch 45/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.4993e-04 - val_loss: 6.4412e-04
# Epoch 46/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.3425e-04 - val_loss: 5.3060e-04
# Epoch 47/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.8263e-04 - val_loss: 5.0673e-04
# Epoch 48/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.9659e-04 - val_loss: 5.0413e-04
# Epoch 49/100
# 10/10 [==============================] - 1s 92ms/step - loss: 8.2189e-04 - val_loss: 4.9795e-04
# Epoch 50/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.0920e-04 - val_loss: 5.0953e-04
# Epoch 51/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.1696e-04 - val_loss: 4.9036e-04
# Epoch 52/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.3198e-04 - val_loss: 5.1542e-04
# Epoch 53/100
# 10/10 [==============================] - 1s 92ms/step - loss: 6.8308e-04 - val_loss: 4.9912e-04
# Epoch 54/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.0604e-04 - val_loss: 4.7111e-04
# Epoch 55/100
# 10/10 [==============================] - 1s 89ms/step - loss: 7.0532e-04 - val_loss: 4.7326e-04
# Epoch 56/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.9155e-04 - val_loss: 7.4704e-04
# Epoch 57/100
# 10/10 [==============================] - 1s 89ms/step - loss: 7.2014e-04 - val_loss: 6.1035e-04
# Epoch 58/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.8662e-04 - val_loss: 4.5737e-04
# Epoch 59/100
# 10/10 [==============================] - 1s 92ms/step - loss: 7.6538e-04 - val_loss: 5.3786e-04
# Epoch 60/100
# 10/10 [==============================] - 1s 91ms/step - loss: 8.7668e-04 - val_loss: 5.7051e-04
# Epoch 61/100
# 10/10 [==============================] - 1s 93ms/step - loss: 7.6034e-04 - val_loss: 4.7061e-04
# Epoch 62/100
# 10/10 [==============================] - 1s 93ms/step - loss: 7.4029e-04 - val_loss: 4.5386e-04
# Epoch 63/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.8853e-04 - val_loss: 4.5762e-04
# Epoch 64/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.4752e-04 - val_loss: 4.4375e-04
# Epoch 65/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.8746e-04 - val_loss: 4.4289e-04
# Epoch 66/100
# 10/10 [==============================] - 1s 93ms/step - loss: 6.9820e-04 - val_loss: 4.6326e-04
# Epoch 67/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.5904e-04 - val_loss: 5.1036e-04
# Epoch 68/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.8304e-04 - val_loss: 8.1272e-04
# Epoch 69/100
# 10/10 [==============================] - 1s 89ms/step - loss: 8.0967e-04 - val_loss: 5.9494e-04
# Epoch 70/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.3380e-04 - val_loss: 0.0011
# Epoch 71/100
# 10/10 [==============================] - 1s 90ms/step - loss: 9.1498e-04 - val_loss: 8.5893e-04
# Epoch 72/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.1117e-04 - val_loss: 6.0796e-04
# Epoch 73/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.5665e-04 - val_loss: 8.9337e-04
# Epoch 74/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.7242e-04 - val_loss: 4.9115e-04
# Epoch 75/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.8491e-04 - val_loss: 4.3398e-04
# Epoch 76/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.2910e-04 - val_loss: 4.5901e-04
# Epoch 77/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.2847e-04 - val_loss: 4.8868e-04
# Epoch 78/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.8170e-04 - val_loss: 4.3618e-04
# Epoch 79/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.4733e-04 - val_loss: 4.8318e-04
# Epoch 80/100
# 10/10 [==============================] - 1s 90ms/step - loss: 7.0381e-04 - val_loss: 4.2800e-04
# Epoch 81/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.6400e-04 - val_loss: 4.2118e-04
# Epoch 82/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.7840e-04 - val_loss: 4.1991e-04
# Epoch 83/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.9435e-04 - val_loss: 6.4544e-04
# Epoch 84/100
# 10/10 [==============================] - 1s 89ms/step - loss: 7.3078e-04 - val_loss: 7.2301e-04
# Epoch 85/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.9590e-04 - val_loss: 5.0091e-04
# Epoch 86/100
# 10/10 [==============================] - 1s 91ms/step - loss: 6.2837e-04 - val_loss: 4.7004e-04
# Epoch 87/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.4080e-04 - val_loss: 4.0709e-04
# Epoch 88/100
# 10/10 [==============================] - 1s 91ms/step - loss: 7.0447e-04 - val_loss: 4.0178e-04
# Epoch 89/100
# 10/10 [==============================] - 1s 93ms/step - loss: 6.3357e-04 - val_loss: 4.2418e-04
# Epoch 90/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.4924e-04 - val_loss: 4.0357e-04
# Epoch 91/100
# 10/10 [==============================] - 1s 89ms/step - loss: 6.5354e-04 - val_loss: 4.5892e-04
# Epoch 92/100
# 10/10 [==============================] - 1s 90ms/step - loss: 6.1620e-04 - val_loss: 4.1322e-04
# Epoch 93/100
# 10/10 [==============================] - 1s 86ms/step - loss: 6.3336e-04 - val_loss: 4.7468e-04
# Epoch 94/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.8373e-04 - val_loss: 4.0592e-04
# Epoch 95/100
# 10/10 [==============================] - 1s 85ms/step - loss: 6.9067e-04 - val_loss: 4.0732e-04
# Epoch 96/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.2678e-04 - val_loss: 3.9926e-04
# Epoch 97/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.9640e-04 - val_loss: 4.0394e-04
# Epoch 98/100
# 10/10 [==============================] - 1s 80ms/step - loss: 6.6578e-04 - val_loss: 4.7412e-04
# Epoch 99/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.6389e-04 - val_loss: 6.0279e-04
# Epoch 100/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.5245e-04 - val_loss: 4.8136e-04
# Learning time:  101.58194398880005 seconds
# 19/19 [==============================] - 1s 17ms/step
# 7/7 [==============================] - 0s 16ms/step
# Train RMSE:  9.645033350783569
# Test RMSE:  8.466386664359087
