# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.layers import GRU
import time

# get SPY data
symbol = "TSLA"
start_date = "2020-01-01"
end_date = "2023-09-01"
data = yf.download(symbol, start=start_date, end=end_date)

# get VIX data
vix_data = yf.download("^VIX", start=start_date, end=end_date)
vix_data = vix_data[['Close']]

# make data set 
data = data.join(vix_data, rsuffix='_VIX')

# delete NaN 
data = data.fillna(method='ffill')

# 'Close', 'Volume', 'Close_VIX' - input features 
price_volume_vix_data = data[['Close', 'Volume', 'Close_VIX']].values

# data scaling
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(price_volume_vix_data)

# split train and test set
train_size = int(len(scaled_data) * 0.7)
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

# create dataset 
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), :]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 60
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# build GRU model
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # input layer
model.add(GRU(50, return_sequences=True))  # hidden layer
model.add(GRU(50))  # hidden layer
model.add(Dense(1))  # output layer
model.compile(loss='mean_squared_error', optimizer='adam')

# summarize model
model.summary()

# check the running time
start_time = time.time()

# training model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64, verbose=1)

# end to check the time
end_time = time.time()

# print the running time
print("Learning time: ", end_time - start_time, "seconds")

# prediction
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# transform it to original scale
train_predict = scaler.inverse_transform(np.column_stack((train_predict, np.zeros_like(train_predict), np.zeros_like(train_predict))))
test_predict = scaler.inverse_transform(np.column_stack((test_predict, np.zeros_like(test_predict), np.zeros_like(test_predict))))
train_predict = train_predict[:, 0]
test_predict = test_predict[:, 0]


Y_train_2d = np.expand_dims(Y_train, axis=1)
Y_test_2d = np.expand_dims(Y_test, axis=1)

trainY_original = scaler.inverse_transform(np.column_stack((Y_train_2d, np.zeros_like(Y_train_2d), np.zeros_like(Y_train_2d))))[:, 0]
testY_original = scaler.inverse_transform(np.column_stack((Y_test_2d, np.zeros_like(Y_test_2d), np.zeros_like(Y_test_2d))))[:, 0]

# get RMSE
print("Train RMSE: ", np.sqrt(mean_squared_error(trainY_original, train_predict)))
print("Test RMSE: ", np.sqrt(mean_squared_error(testY_original, test_predict)))

# plotting
look_back = 60
trainPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
trainPredictPlot[:] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back] = train_predict

testPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1:len(scaled_data) - 1] = test_predict

plt.plot(scaler.inverse_transform(scaled_data)[:, 0])
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 60, 50)            8250
#
#  gru_4 (GRU)                 (None, 60, 50)            15300
#
#  gru_5 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38901 (151.96 KB)
# Trainable params: 38901 (151.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 8s 227ms/step - loss: 0.1032 - val_loss: 0.0428
# Epoch 2/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0157 - val_loss: 0.0051
# Epoch 3/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0053 - val_loss: 0.0099
# Epoch 4/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 5/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0026 - val_loss: 0.0037
# Epoch 6/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 7/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 8/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 9/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 10/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 11/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 12/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 13/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 14/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 9.9570e-04
# Epoch 15/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 16/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 17/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 18/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0012 - val_loss: 9.5748e-04
# Epoch 19/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 20/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 8.7265e-04
# Epoch 21/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 22/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 23/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 24/100
# 10/10 [==============================] - 1s 84ms/step - loss: 9.9775e-04 - val_loss: 8.2079e-04
# Epoch 25/100
# 10/10 [==============================] - 1s 82ms/step - loss: 9.7030e-04 - val_loss: 8.5284e-04
# Epoch 26/100
# 10/10 [==============================] - 1s 84ms/step - loss: 9.4265e-04 - val_loss: 7.7561e-04
# Epoch 27/100
# 10/10 [==============================] - 1s 86ms/step - loss: 9.2588e-04 - val_loss: 7.6109e-04
# Epoch 28/100
# 10/10 [==============================] - 1s 84ms/step - loss: 9.4723e-04 - val_loss: 6.6730e-04
# Epoch 29/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0010 - val_loss: 9.4992e-04
# Epoch 30/100
# 10/10 [==============================] - 1s 84ms/step - loss: 8.9816e-04 - val_loss: 0.0011
# Epoch 31/100
# 10/10 [==============================] - 1s 84ms/step - loss: 9.6901e-04 - val_loss: 9.5418e-04
# Epoch 32/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0010 - val_loss: 8.1843e-04
# Epoch 33/100
# 10/10 [==============================] - 1s 84ms/step - loss: 8.8264e-04 - val_loss: 7.7220e-04
# Epoch 34/100
# 10/10 [==============================] - 1s 83ms/step - loss: 8.3308e-04 - val_loss: 6.9521e-04
# Epoch 35/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.3156e-04 - val_loss: 6.0522e-04
# Epoch 36/100
# 10/10 [==============================] - 1s 82ms/step - loss: 9.0584e-04 - val_loss: 6.1698e-04
# Epoch 37/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.6493e-04 - val_loss: 7.9691e-04
# Epoch 38/100
# 10/10 [==============================] - 1s 82ms/step - loss: 9.1101e-04 - val_loss: 6.4785e-04
# Epoch 39/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.9230e-04 - val_loss: 5.5927e-04
# Epoch 40/100
# 10/10 [==============================] - 1s 84ms/step - loss: 8.2096e-04 - val_loss: 5.4803e-04
# Epoch 41/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.3139e-04 - val_loss: 5.5240e-04
# Epoch 42/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.6829e-04 - val_loss: 5.5341e-04
# Epoch 43/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.7848e-04 - val_loss: 5.9530e-04
# Epoch 44/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.4435e-04 - val_loss: 5.4707e-04
# Epoch 45/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.4706e-04 - val_loss: 5.3867e-04
# Epoch 46/100
# 10/10 [==============================] - 1s 84ms/step - loss: 8.9383e-04 - val_loss: 5.1886e-04
# Epoch 47/100
# 10/10 [==============================] - 1s 84ms/step - loss: 8.1781e-04 - val_loss: 5.9134e-04
# Epoch 48/100
# 10/10 [==============================] - 1s 80ms/step - loss: 8.4839e-04 - val_loss: 5.0420e-04
# Epoch 49/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.6693e-04 - val_loss: 5.1086e-04
# Epoch 50/100
# 10/10 [==============================] - 1s 82ms/step - loss: 8.0620e-04 - val_loss: 5.0162e-04
# Epoch 51/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.8367e-04 - val_loss: 5.3367e-04
# Epoch 52/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.9526e-04 - val_loss: 4.9115e-04
# Epoch 53/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.4074e-04 - val_loss: 4.9010e-04
# Epoch 54/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.0108e-04 - val_loss: 6.4497e-04
# Epoch 55/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.4572e-04 - val_loss: 5.0158e-04
# Epoch 56/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.5329e-04 - val_loss: 4.7973e-04
# Epoch 57/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.9236e-04 - val_loss: 4.9032e-04
# Epoch 58/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.2365e-04 - val_loss: 4.8719e-04
# Epoch 59/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.8627e-04 - val_loss: 4.6932e-04
# Epoch 60/100
# 10/10 [==============================] - 1s 81ms/step - loss: 7.1818e-04 - val_loss: 4.6247e-04
# Epoch 61/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.9807e-04 - val_loss: 5.0498e-04
# Epoch 62/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.6786e-04 - val_loss: 6.6883e-04
# Epoch 63/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.9783e-04 - val_loss: 5.9757e-04
# Epoch 64/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.6063e-04 - val_loss: 6.9137e-04
# Epoch 65/100
# 10/10 [==============================] - 1s 80ms/step - loss: 7.0611e-04 - val_loss: 5.5436e-04
# Epoch 66/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.2469e-04 - val_loss: 4.4292e-04
# Epoch 67/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.6271e-04 - val_loss: 4.8730e-04
# Epoch 68/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.5120e-04 - val_loss: 4.3880e-04
# Epoch 69/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.9992e-04 - val_loss: 4.6169e-04
# Epoch 70/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.5744e-04 - val_loss: 4.6545e-04
# Epoch 71/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.4839e-04 - val_loss: 4.3609e-04
# Epoch 72/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.2227e-04 - val_loss: 4.3152e-04
# Epoch 73/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.6007e-04 - val_loss: 6.5664e-04
# Epoch 74/100
# 10/10 [==============================] - 1s 82ms/step - loss: 7.5446e-04 - val_loss: 6.0679e-04
# Epoch 75/100
# 10/10 [==============================] - 1s 81ms/step - loss: 6.9945e-04 - val_loss: 5.0759e-04
# Epoch 76/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.5617e-04 - val_loss: 4.4906e-04
# Epoch 77/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.4384e-04 - val_loss: 4.2622e-04
# Epoch 78/100
# 10/10 [==============================] - 1s 83ms/step - loss: 6.4512e-04 - val_loss: 4.1817e-04
# Epoch 79/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.5353e-04 - val_loss: 5.6681e-04
# Epoch 80/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.9978e-04 - val_loss: 7.4099e-04
# Epoch 81/100
# 10/10 [==============================] - 1s 86ms/step - loss: 7.1877e-04 - val_loss: 4.7311e-04
# Epoch 82/100
# 10/10 [==============================] - 1s 85ms/step - loss: 6.2402e-04 - val_loss: 6.3104e-04
# Epoch 83/100
# 10/10 [==============================] - 1s 83ms/step - loss: 7.0744e-04 - val_loss: 9.2452e-04
# Epoch 84/100
# 10/10 [==============================] - 1s 84ms/step - loss: 9.6083e-04 - val_loss: 5.2116e-04
# Epoch 85/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.3977e-04 - val_loss: 4.2436e-04
# Epoch 86/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.8475e-04 - val_loss: 4.1583e-04
# Epoch 87/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.5773e-04 - val_loss: 4.3126e-04
# Epoch 88/100
# 10/10 [==============================] - 1s 85ms/step - loss: 6.8552e-04 - val_loss: 4.1449e-04
# Epoch 89/100
# 10/10 [==============================] - 1s 85ms/step - loss: 6.2040e-04 - val_loss: 4.2162e-04
# Epoch 90/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.2482e-04 - val_loss: 5.6126e-04
# Epoch 91/100
# 10/10 [==============================] - 1s 82ms/step - loss: 6.3942e-04 - val_loss: 5.2876e-04
# Epoch 92/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.5302e-04 - val_loss: 4.8732e-04
# Epoch 93/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.2595e-04 - val_loss: 4.6897e-04
# Epoch 94/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.5988e-04 - val_loss: 4.8303e-04
# Epoch 95/100
# 10/10 [==============================] - 1s 84ms/step - loss: 7.1149e-04 - val_loss: 4.2404e-04
# Epoch 96/100
# 10/10 [==============================] - 1s 85ms/step - loss: 6.7138e-04 - val_loss: 6.0438e-04
# Epoch 97/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.7154e-04 - val_loss: 4.1248e-04
# Epoch 98/100
# 10/10 [==============================] - 1s 86ms/step - loss: 6.3152e-04 - val_loss: 4.4788e-04
# Epoch 99/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.2946e-04 - val_loss: 4.0993e-04
# Epoch 100/100
# 10/10 [==============================] - 1s 84ms/step - loss: 6.5112e-04 - val_loss: 4.6776e-04
# Learning time:  89.8799045085907 seconds
# 19/19 [==============================] - 1s 17ms/step
# 7/7 [==============================] - 0s 16ms/step
# Train RMSE:  9.579447512952646
# Test RMSE:  8.345892675640183
