# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import time

# get SPY data
symbol = "TSLA"
start_date = "2020-01-01"
end_date = "2023-09-01"
data = yf.download(symbol, start=start_date, end=end_date)

# get VIX data
vix_data = yf.download("^VIX", start=start_date, end=end_date)
vix_data = vix_data[['Close']]

# make data set 
data = data.join(vix_data, rsuffix='_VIX')

# delete NaN 
data = data.fillna(method='ffill')

# 'Close', 'Volume', 'Close_VIX' - input features 
price_volume_vix_data = data[['Close', 'Volume', 'Close_VIX']].values

# data scaling
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(price_volume_vix_data)

# split train and test set
train_size = int(len(scaled_data) * 0.7)
test_size = len(scaled_data) - train_size
train_data, test_data = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

# create dataset 
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), :]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 60
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # 입력층
model.add(LSTM(50, return_sequences=True))  # hidden layer
model.add(LSTM(50))  # hidden layer
model.add(Dense(1))  # output layer
model.compile(loss='mean_squared_error', optimizer='adam')

# summarize model
model.summary()

# check the running time
start_time = time.time()

# training model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64, verbose=1)

# end to check the time
end_time = time.time()

# print the running time
print("Learning time: ", end_time - start_time, "seconds")

# prediction
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# transform it to original scale
train_predict = scaler.inverse_transform(np.column_stack((train_predict, np.zeros_like(train_predict), np.zeros_like(train_predict))))
test_predict = scaler.inverse_transform(np.column_stack((test_predict, np.zeros_like(test_predict), np.zeros_like(test_predict))))
train_predict = train_predict[:, 0]
test_predict = test_predict[:, 0]


Y_train_2d = np.expand_dims(Y_train, axis=1)
Y_test_2d = np.expand_dims(Y_test, axis=1)

trainY_original = scaler.inverse_transform(np.column_stack((Y_train_2d, np.zeros_like(Y_train_2d), np.zeros_like(Y_train_2d))))[:, 0]
testY_original = scaler.inverse_transform(np.column_stack((Y_test_2d, np.zeros_like(Y_test_2d), np.zeros_like(Y_test_2d))))[:, 0]

# get RMSE
print("Train RMSE: ", np.sqrt(mean_squared_error(trainY_original, train_predict)))
print("Test RMSE: ", np.sqrt(mean_squared_error(testY_original, test_predict)))

# plotting
look_back = 60
trainPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
trainPredictPlot[:] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back] = train_predict

testPredictPlot = np.empty_like(price_volume_vix_data[:, 0])
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1:len(scaled_data) - 1] = test_predict

plt.plot(scaler.inverse_transform(scaled_data)[:, 0])
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60, 50)            10800
#
#  lstm_7 (LSTM)               (None, 60, 50)            20200
#
#  lstm_8 (LSTM)               (None, 50)                20200
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 51251 (200.20 KB)
# Trainable params: 51251 (200.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 8s 224ms/step - loss: 0.0833 - val_loss: 0.0069
# Epoch 2/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0188 - val_loss: 0.0114
# Epoch 3/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0091 - val_loss: 0.0051
# Epoch 4/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0076 - val_loss: 0.0108
# Epoch 5/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 6/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 7/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0048 - val_loss: 0.0065
# Epoch 8/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 9/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0044 - val_loss: 0.0069
# Epoch 10/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 11/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 12/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 13/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 14/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 15/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 16/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 17/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 18/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 19/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 20/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 21/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 22/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 23/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 24/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 25/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 26/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 27/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 28/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 29/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 30/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 31/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 32/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 33/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 34/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 35/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 36/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 37/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 38/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 39/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 40/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 41/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 42/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 43/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 44/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 45/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 46/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 47/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 48/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 49/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 50/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 51/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 52/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 53/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 54/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 55/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 56/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 57/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 58/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 59/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 60/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 61/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 62/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 63/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 64/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 65/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 66/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 67/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 68/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 69/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 70/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 71/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 72/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 73/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 74/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 75/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 76/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 77/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 78/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 79/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 80/100
# 10/10 [==============================] - 1s 101ms/step - loss: 9.9267e-04 - val_loss: 0.0013
# Epoch 81/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 82/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 83/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 84/100
# 10/10 [==============================] - 1s 101ms/step - loss: 9.4372e-04 - val_loss: 0.0013
# Epoch 85/100
# 10/10 [==============================] - 1s 100ms/step - loss: 9.7839e-04 - val_loss: 0.0020
# Epoch 86/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 87/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 88/100
# 10/10 [==============================] - 1s 102ms/step - loss: 9.4380e-04 - val_loss: 0.0014
# Epoch 89/100
# 10/10 [==============================] - 1s 101ms/step - loss: 9.2555e-04 - val_loss: 0.0013
# Epoch 90/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 91/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 92/100
# 10/10 [==============================] - 1s 102ms/step - loss: 9.6620e-04 - val_loss: 0.0017
# Epoch 93/100
# 10/10 [==============================] - 1s 100ms/step - loss: 9.8779e-04 - val_loss: 0.0014
# Epoch 94/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 95/100
# 10/10 [==============================] - 1s 102ms/step - loss: 9.1370e-04 - val_loss: 0.0014
# Epoch 96/100
# 10/10 [==============================] - 1s 103ms/step - loss: 8.9941e-04 - val_loss: 0.0016
# Epoch 97/100
# 10/10 [==============================] - 1s 102ms/step - loss: 8.5530e-04 - val_loss: 0.0018
# Epoch 98/100
# 10/10 [==============================] - 1s 102ms/step - loss: 9.4460e-04 - val_loss: 0.0013
# Epoch 99/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 100/100
# 10/10 [==============================] - 1s 101ms/step - loss: 9.2162e-04 - val_loss: 0.0024
# Learning time:  105.3074140548706 seconds
# 19/19 [==============================] - 1s 22ms/step
# 7/7 [==============================] - 0s 23ms/step
# Train RMSE:  13.683337982310345
# Test RMSE:  18.806831758088645
